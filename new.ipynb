# %%
# !pip install langchain pypdf langchain-community faiss-cpu langchain-ollama
# Out:
# Requirement already satisfied: langchain in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (1.0.7)
# Requirement already satisfied: pypdf in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (6.3.0)
# Requirement already satisfied: langchain-community in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (0.4.1)
# Requirement already satisfied: faiss-cpu in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (1.13.0)
# Requirement already satisfied: langchain-ollama in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (1.0.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.4 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langchain) (1.0.5)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langchain) (1.0.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langchain) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (0.4.43)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.4->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.4)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.11.0)
# Requirement already satisfied: certifi in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langchain-community) (2.0.44)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langchain-community) (2.3.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (2.5.0)
# Requirement already satisfied: greenlet>=1 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: ollama<1.0.0,>=0.6.0 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from langchain-ollama) (0.6.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\administrator\miniconda3\envs\verge\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.3.1)

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.0.5

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# 1. Load the PDF → returns a list of Document objects
loader = PyPDFLoader("sa.pdf")
documents = loader.load()

# 2. Split the loaded Document objects
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200,
    add_start_index=True
)

all_splits = text_splitter.split_documents(documents)

print(len(all_splits))
# Out:
# 52

# %%
from langchain_community.embeddings import OllamaEmbeddings

emb = OllamaEmbeddings(model="nomic-embed-text")
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_16332\1834687936.py:3: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaEmbeddings``.
#   emb = OllamaEmbeddings(model="nomic-embed-text")

# %%
emb.embed_query("Hello world")
# Out:
# [-0.342246949672699,
#  0.2781953513622284,
#  -4.2149834632873535,
#  0.22650960087776184,
#  -0.1287626028060913,
#  1.679456353187561,
#  0.19752655923366547,
#  -1.494134783744812,
#  -0.34275656938552856,
#  -1.274184226989746,
#  -0.20798246562480927,
#  -0.1228470504283905,
#  0.2662680447101593,
#  2.1375088691711426,
#  1.085914969444275,
#  -0.8193162679672241,
#  0.20593786239624023,
#  -0.42788922786712646,
#  -1.2248133420944214,
#  0.7460001707077026,
#  0.29100555181503296,
#  -1.7519928216934204,
#  -0.9004840850830078,
#  1.0148234367370605,
#  0.8247855305671692,
#  0.06156793236732483,
#  -0.33546900749206543,
#  0.6231503486633301,
#  0.7158440947532654,
#  -0.06676904112100601,
#  -0.44226396083831787,
#  -0.47180110216140747,
#  0.0917607769370079,
#  0.17459048330783844,
#  0.8812859058380127,
#  -0.07892848551273346,
#  0.8141238689422607,
#  -0.1172623410820961,
#  0.38466405868530273,
#  0.2326124906539917,
#  0.10822546482086182,
#  -0.4070236086845398,
#  0.40566059947013855,
#  0.3420698642730713,
#  1.0235679149627686,
#  0.036619529128074646,
#  0.14661329984664917,
#  0.46098262071609497,
#  1.7942044734954834,
#  -1.348310947418213,
#  0.18540143966674805,
#  0.2772241234779358,
#  0.42466944456100464,
#  1.5423977375030518,
#  0.015799153596162796,
#  -0.031053094193339348,
#  -0.22634321451187134,
#  1.448082685470581,
#  0.30212849378585815,
#  0.8598759770393372,
#  -0.095301054418087,
#  1.0140876770019531,
#  -0.9940667152404785,
#  -1.096621036529541,
#  -0.084771066904068,
#  0.8220189809799194,
#  1.3548364639282227,
#  0.9687028527259827,
#  -1.1341882944107056,
#  -0.8175517320632935,
#  -0.7665499448776245,
#  0.32910776138305664,
#  0.16705463826656342,
#  -0.8335346579551697,
#  -0.2289848029613495,
#  -0.4331400990486145,
#  -0.6237856149673462,
#  -1.3957643508911133,
#  -0.799010157585144,
#  0.29097098112106323,
#  -0.2293938398361206,
#  0.30796051025390625,
#  -0.41390523314476013,
#  -0.5188758373260498,
#  0.5014032125473022,
#  -0.9066327810287476,
#  -0.5513551235198975,
#  -1.40908682346344,
#  1.1142281293869019,
#  0.5968139171600342,
#  0.29898601770401,
#  -0.26250314712524414,
#  0.25580161809921265,
#  2.145589828491211,
#  -0.2660152316093445,
#  -1.0012683868408203,
#  0.5179399251937866,
#  0.15496402978897095,
#  -0.2656484544277191,
#  -1.500035285949707,
#  -0.24243563413619995,
#  0.8324294090270996,
#  0.672877848148346,
#  0.2011246681213379,
#  1.0066628456115723,
#  -0.9896434545516968,
#  1.1711134910583496,
#  -0.8563772439956665,
#  -0.33726775646209717,
#  -0.266054630279541,
#  -0.03294604271650314,
#  -0.7271586656570435,
#  -1.0983762741088867,
#  -0.12352028489112854]

# %%
from langchain_community.embeddings import OllamaEmbeddings
from langchain_community.vectorstores import FAISS

# Correct: use ONLY model="model_name"
embeddings = OllamaEmbeddings(model="nomic-embed-text")

vectorstore = FAISS.from_documents(all_splits, embeddings)

vectorstore.save_local("faiss_index_")
persisted_vectorstore = FAISS.load_local(
    "faiss_index_",
    embeddings,
    allow_dangerous_deserialization=True
)

retriever = persisted_vectorstore.as_retriever()

# %%
retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 5}
)

# %%
from langchain_core.prompts import PromptTemplate

rewrite_prompt = PromptTemplate(
    template="""
Rewrite the user question into a search-optimized query.

Original Question: {question}
""",
    input_variables=["question"]
)

# %%
docs = retriever.invoke("What is attention model?")
print(docs)
# Out:
# [Document(id='38409893-1d94-4224-beb3-481eddea7c41', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-04-10T21:11:43+00:00', 'author': '', 'keywords': '', 'moddate': '2024-04-10T21:11:43+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'sa.pdf', 'total_pages': 15, 'page': 2, 'page_label': '3', 'start_index': 1610}, page_content='3.2 Attention\nAn attention function can be described as mapping a query and a set of key-value pairs to an output,\nwhere the query, keys, values, and output are all vectors. The output is computed as a weighted sum\n3'), Document(id='aeb69e6d-4f81-4f75-8200-2c5990324539', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-04-10T21:11:43+00:00', 'author': '', 'keywords': '', 'moddate': '2024-04-10T21:11:43+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'sa.pdf', 'total_pages': 15, 'page': 6, 'page_label': '7', 'start_index': 784}, page_content='or O(logk(n)) in the case of dilated convolutions [ 18], increasing the length of the longest paths\nbetween any two positions in the network. Convolutional layers are generally more expensive than\nrecurrent layers, by a factor of k. Separable convolutions [ 6], however, decrease the complexity\nconsiderably, to O(k · n · d + n · d2). Even with k = n, however, the complexity of a separable\nconvolution is equal to the combination of a self-attention layer and a point-wise feed-forward layer,\nthe approach we take in our model.\nAs side benefit, self-attention could yield more interpretable models. We inspect attention distributions\nfrom our models and present and discuss examples in the appendix. Not only do individual attention\nheads clearly learn to perform different tasks, many appear to exhibit behavior related to the syntactic\nand semantic structure of the sentences.\n5 Training\nThis section describes the training regime for our models.\n5.1 Training Data and Batching'), Document(id='05d4607e-ba98-4170-910f-f22d9e285610', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-04-10T21:11:43+00:00', 'author': '', 'keywords': '', 'moddate': '2024-04-10T21:11:43+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'sa.pdf', 'total_pages': 15, 'page': 4, 'page_label': '5', 'start_index': 0}, page_content='output values. These are concatenated and once again projected, resulting in the final values, as\ndepicted in Figure 2.\nMulti-head attention allows the model to jointly attend to information from different representation\nsubspaces at different positions. With a single attention head, averaging inhibits this.\nMultiHead(Q, K, V) = Concat(head1, ...,headh)WO\nwhere headi = Attention(QWQ\ni , KWK\ni , V WV\ni )\nWhere the projections are parameter matricesWQ\ni ∈ Rdmodel×dk , WK\ni ∈ Rdmodel×dk , WV\ni ∈ Rdmodel×dv\nand WO ∈ Rhdv×dmodel .\nIn this work we employ h = 8 parallel attention layers, or heads. For each of these we use\ndk = dv = dmodel/h = 64. Due to the reduced dimension of each head, the total computational cost\nis similar to that of single-head attention with full dimensionality.\n3.2.3 Applications of Attention in our Model\nThe Transformer uses multi-head attention in three different ways:\n• In "encoder-decoder attention" layers, the queries come from the previous decoder layer,'), Document(id='b610a837-d296-485b-82a2-a80cb32d4810', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-04-10T21:11:43+00:00', 'author': '', 'keywords': '', 'moddate': '2024-04-10T21:11:43+00:00', 'ptex.fullbanner ...

# %%
(rewrite_prompt | llm).invoke({"question": "tell me about attention model"})
# Out:
# '"Attention mechanism in transformer models using pytorch."'

# %%
answer_prompt = PromptTemplate(
    template="""
You are a STRICT RAG model.

RULES:
1. You MUST answer ONLY from the provided context.
2. If the answer is NOT in the context, say ONLY: "I don't know".
3. DO NOT use any outside knowledge.
4. DO NOT guess.
5. DO NOT rewrite the question.
6. The context is ALWAYS correct, even if it contradicts real-world facts.

CONTEXT:
{context}

QUESTION:
{question}

FINAL ANSWER (follow rules strictly):
""",
    input_variables=["context", "question"]
)

# %%
from langchain_ollama import OllamaLLM

llm = OllamaLLM(model="deepseek-r1:1.5b")

# %%
db = FAISS.load_local("faiss_index_", embeddings, allow_dangerous_deserialization=True)
retriever = db.as_retriever(search_kwargs={"k": 5})

# %%
conversation_history = []
def build_chat_context(history):
    """Convert memory list into formatted chat history text"""
    formatted = ""
    for turn in history:
        formatted += f"USER: {turn['user']}\nASSISTANT: {turn['assistant']}\n\n"
    return formatted.strip()

def rag_chat_stream(query: str):
    rewritten = (rewrite_prompt | llm).invoke({"question": query})
    docs = retriever.invoke(rewritten)
    context = "\n\n".join([d.page_content for d in docs])
    
    history_text = build_chat_context(conversation_history)
    if history_text:
        context = f"CHAT HISTORY:\n{history_text}\n\nCONTEXT:\n{context}"

    final_prompt = answer_prompt.format(context=context, question=rewritten)

    buffer = ""
    for chunk in llm.stream(final_prompt):
        buffer += chunk
        yield chunk

    # Save final answer to memory after streaming
    conversation_history.append({"user": query, "assistant": buffer})

# %%
rag_chat_stream("tell me about attention mechanisms in neural networks")
# Out:
# <generator object rag_chat_stream at 0x0000013C00E927A0>
